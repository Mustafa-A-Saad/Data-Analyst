# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt 
plt.style.use('ggplot') # similar to sns.set_style()
# %matplotlib inline

# %%
df = pd.read_csv("Excels\\coaster_db.csv")
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.isna().sum()
# Out:
# coaster_name                        0
# Length                            134
# Speed                             150
# Location                            0
# Status                            213
# Opening date                      250
# Type                                0
# Manufacturer                       59
# Height restriction                256
# Model                             343
# Height                            122
# Inversions                        155
# Lift/launch system                292
# Cost                              705
# Trains                            369
# Park section                      600
# Duration                          322
# Capacity                          512
# G-force                           725
# Designer                          509
# Max vertical angle                730
# Drop                              593
# Soft opening date                 991
# Fast Lane available              1018
# Replaced                          914
# ...

# %%
df.describe(percentiles=[])
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# min      5.000000      4.000000   13.100000          0.000000      0.800000
# 50%     49.700000     79.000000   91.200000          0.000000      4.000000
# ...

# %%
df = df[['coaster_name',
    #'Length', 'Speed',
    'Location', 'Status', 
    #'Opening date',
     #  'Type',
    'Manufacturer',
    # 'Height restriction', 'Model', 'Height',
     #  'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
      # 'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
      # 'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
      # 'Track layout', 'Fastrack available', 'Soft opening date.1',
     #  'Closing date',
   # 'Opened',
    #'Replaced by', 'Website',
   #    'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
    #   'Single rider line available', 'Restraint Style',
     #  'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced',
    'latitude', 'longitude', 
    'Type_Main',
       'opening_date_clean',
   # 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
      'speed_mph', 
       #  'height_value', 'height_unit',
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df = df.rename(columns={
    'coaster_name' : 'Coaster_Name',
    'year_introduced' : 'Year_Introduced',
    'latitude' : "Latitude",
    'longitude' : "Longitude",
    'opening_date_clean' : 'Open_Date',
    'speed_mph' : 'Speed_mph',
    'height_ft': "Height_ft",
    'Inversions_clean' : 'Inversions',
    'Gforce_clean' : "Gforce"
})

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year_Introduced  Latitude  Longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main   Open_Date  Speed_mph  Height_ft  Inversions  Gforce
# ...

# %%
df['Open_Date'] = pd.to_datetime(df["Open_Date"])

# %%
# DUPLICATES

# %%
df.loc[df.duplicated(subset='Coaster_Name')]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# ...

# %%
df
# Out:
#                                 Coaster_Name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df = df.drop_duplicates(subset=['Coaster_Name','Open_Date']) # Drops duplicates that in Coaster_Name,Open_Date

# %%
df = df.reset_index(drop=True)

# %%
df.to_csv("test.csv")

# %%
df[df['Latitude'].isna()] # prints out all rows where Latitude is NA
# Out:
#                                Coaster_Name                  Location  \
# 6                             Leap-The-Dips             Lakemont Park
# 15                 The Great Scenic Railway       Luna Park Melbourne
# 16                            Zippin Pippin                     Other
# 35              Giant Dipper (Belmont Park)                     Other
# 56            Big Dipper (Luna Park Sydney)                     Other
# ..                                      ...                       ...
# 981            Dr. Diabolical’s Cliffhanger    Six Flags Fiesta Texas
# 983                  Fønix (roller coaster)          Fårup Sommerland
# 984  Guardians of the Galaxy: Cosmic Rewind                     Epcot
# 988                                 Tumbili            Kings Dominion
# 989          Wonder Woman Flight of Courage  Six Flags Magic Mountain
#
#                  Status                  Manufacturer  Year_Introduced  \
# ...

# %%
df.isna().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             146
# Manufacturer        58
# Year_Introduced      0
# Latitude           207
# Longitude          207
# Type_Main            0
# Open_Date          183
# Speed_mph          140
# Height_ft          831
# Inversions           0
# Gforce             666
# dtype: int64

# %%
df['Open_Date'].fillna(method='ffill',inplace=True)

# %%
df.isna().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             146
# Manufacturer        58
# Year_Introduced      0
# Latitude           207
# Longitude          207
# Type_Main            0
# Open_Date            0
# Speed_mph          140
# Height_ft          831
# Inversions           0
# Gforce             666
# dtype: int64

# %%
df.set_index('Open_Date',inplace=True)

# %%
df.interpolate(method='time',inplace=True) # interpolates according to time

# %%
df.fillna(method='bfill',inplace=True)

# %%
df.loc['1884-06-16']
# Out:
# Coaster_Name           Switchback Railway
# Location                     Coney Island
# Status                            Removed
# Manufacturer       LaMarcus Adna Thompson
# Year_Introduced                      1884
# Latitude                           40.574
# Longitude                         -73.978
# Type_Main                            Wood
# Speed_mph                             6.0
# Height_ft                            52.5
# Inversions                              0
# Gforce                                2.9
# Name: 1884-06-16 00:00:00, dtype: object

# %%
# Out:
# (990, 12)

# %%
df['Year_Introduced'].value_counts().head(15).plot(kind='barh',title='Coasters',xlabel='Freq')
# Out:
# <Axes: title={'center': 'Coasters'}, xlabel='Freq', ylabel='Year_Introduced'>

# %%
df['Speed_mph'].plot(kind='hist',bins=20,edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Speed_mph'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.head()
# Out:
#                                       Coaster_Name  \
# Open_Date
# 1884-06-16                      Switchback Railway
# 1895-01-01                       Flip Flap Railway
# 1895-01-01  Switchback Railway (Euclid Beach Park)
# 1901-01-01            Loop the Loop (Coney Island)
# 1901-01-01            Loop the Loop (Young's Pier)
#
#                                   Location   Status            Manufacturer  \
# Open_Date
# 1884-06-16                    Coney Island  Removed  LaMarcus Adna Thompson
# 1895-01-01                   Sea Lion Park  Removed            Lina Beecher
# 1895-01-01  Cleveland, Ohio, United States   Closed          Edwin Prescott
# 1901-01-01                           Other  Removed          Edwin Prescott
# 1901-01-01                           Other  Removed          Edwin Prescott
#
#             Year_Introduced  Latitude  Longitude Type_Main  Speed_mph  \
# Open_Date
# 1884-06-16             1884   40.5740   -73.9780      Wood   6.000000
# ...

# %%
sns.scatterplot(x='Speed_mph',y='Height_ft',data=df.head(500),hue='Year_Introduced')
# Out:
# <Axes: xlabel='Speed_mph', ylabel='Height_ft'>

# %%
df_corr = df[['Year_Introduced','Speed_mph','Height_ft','Inversions','Gforce']].corr()
df_corr
# Out:
#                  Year_Introduced  Speed_mph  Height_ft  Inversions    Gforce
# Year_Introduced         1.000000   0.299113   0.300767    0.233701 -0.181024
# Speed_mph               0.299113   1.000000   0.300047    0.247092  0.034720
# Height_ft               0.300767   0.300047   1.000000    0.156475  0.073607
# Inversions              0.233701   0.247092   0.156475    1.000000  0.129054
# Gforce                 -0.181024   0.034720   0.073607    0.129054  1.000000

# %%
sns.heatmap(df_corr,annot=True,cmap='magma')
# Out:
# <Axes: >

# %%
sns.pairplot(data=df,vars=['Year_Introduced','Speed_mph','Height_ft','Inversions','Gforce'])
# Out:
# C:\Users\musta\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['Manufacturer'].sample(5)
# Out:
# Open_Date
# 1977-01-01                   Arrow Dynamics
# 2003-04-12                          Intamin
# 2000-02-11                        Giovanola
# 2009-03-14                Anton Schwarzkopf
# 1996-04-30    Custom Coasters International
# Name: Manufacturer, dtype: object

# %%
# What are the locations with the fastest roller coasters (minimum of 10)?

df[df['Location'] != 'Other'].groupby('Location')['Speed_mph'].agg(['mean','count']).query('count >= 10 ').sort_values(by='mean',ascending=False).plot(kind='barh')
# Out:
# <Axes: ylabel='Location'>
