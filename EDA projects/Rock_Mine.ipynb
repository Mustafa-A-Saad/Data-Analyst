# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("Excels\\rock_mine.csv")
df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
df.shape
# Out:
# (207, 61)

# %%
df.describe()
# Out:
#            0.0200      0.0371      0.0428      0.0207      0.0954      0.0986  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#            0.1539      0.1601      0.3109      0.2111  ...      0.0232  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %%
df['R'].value_counts()
# Out:
# R
# M    111
# R     96
# Name: count, dtype: int64

# %%
df.groupby('R').mean()
# Out:
#      0.0200    0.0371    0.0428    0.0207    0.0954    0.0986    0.1539  \
# R
# M  0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R  0.022524  0.030232  0.035879  0.041664  0.061680  0.096199  0.113767
#
#      0.1601    0.3109    0.2111  ...    0.0232    0.0027    0.0065    0.0159  \
# R                                ...
# M  0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R  0.117153  0.135584  0.158785  ...  0.012198  0.010533  0.009673  0.009451
#
#      0.0072    0.0167    0.0180    0.0084    0.0090    0.0032
# R
# M  0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R  0.008581  0.007333  0.007708  0.006659  0.007058  0.006053
#
# [2 rows x 60 columns]

# %%
dummies = pd.get_dummies(df['R'],drop_first = True,prefix='dummy')
dummies
# Out:
#      dummy_R
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# ..       ...
# 202    False
# 203    False
# 204    False
# 205    False
# 206    False
#
# [207 rows x 1 columns]

# %%
df = pd.concat([df,dummies],axis='columns')
df = df.drop(['R'],axis='columns')

# %%
df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  dummy_R
# 0  0.0052  0.0044     True
# 1  0.0095  0.0078     True
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
X = df.drop(['dummy_R'],axis='columns')
y = df['dummy_R']
X_train, X_test, y_train , y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LogisticRegression,LinearRegression

model_params ={ 
    'log_reg' : {
        'model' : LogisticRegression(),
        'params' : {
            'C' : [1,10,20,50]
        }
    },
    'lin_reg': {
        'model' : LinearRegression(),
        'params' : {
            
        }
    }
}

# %%
model_params
# Out:
# {'log_reg': {'model': LogisticRegression(), 'params': {'C': [1, 10, 20, 50]}},
#  'lin_reg': {'model': LinearRegression(), 'params': {}}}

# %%
from sklearn.model_selection import GridSearchCV

scores = []

for model_name,mp in model_params.items():
    clf = GridSearchCV(mp['model'],mp['params'],cv=5)
    clf.fit(X_train,y_train)
    scores.append({
        'model' : model_name,
        'best_score' : clf.best_score_,
        'best_params' : clf.best_params_
    })

pd.DataFrame(scores)
# Out:
#      model  best_score best_params
# 0  log_reg    0.793939    {'C': 1}
# 1  lin_reg   -0.416384          {}

# %%
model = LogisticRegression(C=1).fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.7380952380952381

# %%
#accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, y_train)
print('Accuracy on training data : ', training_data_accuracy)
# Out:
# Accuracy on training data :  0.8666666666666667

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, y_test)
print('Accuracy on test data : ', test_data_accuracy)
# Out:
# Accuracy on test data :  0.7380952380952381

# %%
X_test.head(2)
# Out:
#     0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 58  0.0125  0.0152  0.0218  0.0175  0.0362  0.0696  0.0873  0.0616  0.1252
# 63  0.0071  0.0103  0.0135  0.0494  0.0253  0.0806  0.0701  0.0738  0.0117
#
#     0.2111  ...  0.0232  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  \
# 58  0.1302  ...  0.0019  0.0041  0.0074  0.0030  0.0050  0.0048  0.0017
# 63  0.0898  ...  0.0252  0.0043  0.0048  0.0076  0.0124  0.0105  0.0054
#
#     0.0084  0.0090  0.0032
# 58  0.0041  0.0086  0.0058
# 63  0.0032  0.0073  0.0063
#
# [2 rows x 60 columns]

# %%
prediction = model.predict(X_test)
prediction
# Out:
# array([ True,  True,  True, False,  True,  True, False,  True, False,
#         True, False, False,  True, False,  True, False,  True, False,
#        False, False, False,  True,  True, False,  True, False,  True,
#        False,  True, False, False,  True,  True, False,  True, False,
#        False,  True, False,  True,  True, False])

# %%
for i in range(len(prediction)):
    if prediction[i] == 1:  # Assuming 1 represents 'Rock' class
        print('The object is a Rock')
    else:
        print('The object is a Mine')
# Out:
# The object is a Rock
# The object is a Rock
# The object is a Rock
# The object is a Mine
# The object is a Rock
# The object is a Rock
# The object is a Mine
# The object is a Rock
# The object is a Mine
# The object is a Rock
# The object is a Mine
# The object is a Mine
# The object is a Rock
# The object is a Mine
# The object is a Rock
# The object is a Mine
# The object is a Rock
# The object is a Mine
# The object is a Mine
# The object is a Mine
# The object is a Mine
# The object is a Rock
# The object is a Rock
# The object is a Mine
# The object is a Rock
# The object is a Mine
# The object is a Rock
# The object is a Mine
# The object is a Rock
# The object is a Mine
# The object is a Mine
# The object is a Rock
# The object is a Rock
# The object is a Mine
# The object is a Rock
# The object is a Mine
# The object is a Mine
# The object is a Rock
# The object is a Mine
# The object is a Rock
# The object is a Rock
# The object is a Mine
