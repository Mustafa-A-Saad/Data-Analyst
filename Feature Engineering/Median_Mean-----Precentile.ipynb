# %%
import pandas as pd
import numpy as np

# %%
# Removing Outliers with quantiles

# %%
df = pd.read_csv("Excels\\AB_NYC_2019.csv")
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-21               0.38                               2
# 2             NaN                NaN                               1
# 3      2019-07-05               4.64                               1
# 4      2018-11-19               0.10                               1
# ...           ...                ...                             ...
# 48890         NaN                NaN                               2
# 48891         NaN                NaN                               2
# 48892         NaN                NaN                               1
# 48893         NaN                NaN                               6
# 48894         NaN                NaN                               1
#
#        availability_365
# 0                   365
# 1                   355
# 2                   365
# 3                   194
# 4                     0
# ...                 ...
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23
#
# [48895 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.shape
# Out:
# (48895, 16)

# %%
df['price'].value_counts()
# Out:
# price
# 100    2051
# 150    2047
# 50     1534
# 60     1458
# 200    1401
#        ...
# 780       1
# 386       1
# 888       1
# 483       1
# 338       1
# Name: count, Length: 674, dtype: int64

# %%
df['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
min_threshold,max_threshold = df['price'].quantile([0.01,0.999])
min_threshold,max_threshold
# Out:
# (30.0, 3000.0)

# %%
df[df.price<min_threshold].head()
# Out:
#            id                                           name  host_id  \
# 957    375249                Enjoy Staten Island Hospitality  1887999
# 2675  1428154            Central, Peaceful Semi-Private Room  5912572
# 2860  1620248  Large furnished 2 bedrooms- - 30 days Minimum  2196224
# 3020  1767037             Small Cozy Room Wifi & AC near JFK  9284163
# 3918  2431607                  Bright, Airy Room Share for 2  4973668
#
#         host_name neighbourhood_group       neighbourhood  latitude  \
# 957   Rimma & Jim       Staten Island        Graniteville  40.62109
# 2675      Tangier            Brooklyn            Flatbush  40.63899
# 2860        Sally           Manhattan        East Village  40.73051
# 3020      Antonio              Queens           Woodhaven  40.68968
# 3918       Gloria            Brooklyn  Bedford-Stuyvesant  40.68642
#
#       longitude        room_type  price  minimum_nights  number_of_reviews  \
# 957   -74.16534     Private room     20               3                 80
# 2675  -73.95177      Shared room     29               2                  5
# 2860  -73.98140  Entire home/apt     10              30                  0
# 3020  -73.85219     Private room     29               2                386
# 3918  -73.93440      Shared room     25               5                 76
#
#      last_review  reviews_per_month  calculated_host_listings_count  \
# 957   2019-05-26               0.92                               1
# 2675  2014-10-20               0.07                               1
# 2860         NaN                NaN                               4
# 3020  2019-06-19               5.53                               3
# 3918  2019-06-06               1.22                               3
#
#       availability_365
# 957                226
# 2675               321
# 2860               137
# 3020                50
# 3918               258

# %%
df2 = df[ (df.price>min_threshold)&(df.price<max_threshold)]
df2.shape
# Out:
# (48183, 16)

# %%
df2.sample(5)
# Out:
#              id                                           name    host_id  \
# 19877  15929281     new Private room Near Tompkins square park    1810885
# 28876  22267769           Cosy room in a cool Williamsburg Apt   72593389
# 20171  16148691  Lovely 2 bed/2 bath 15 min. from TIMES SQUARE    3912009
# 43801  33881136                          Cozy Brooklyn Getaway  255856907
# 33740  26744053                                   Private Room  200933726
#
#       host_name neighbourhood_group  neighbourhood  latitude  longitude  \
# 19877      Alex           Manhattan   East Village  40.72468  -73.97830
# 28876    Jeremy            Brooklyn   Williamsburg  40.71353  -73.96216
# 20171   Brendan           Manhattan         Harlem  40.82408  -73.94643
# 43801    Chanel            Brooklyn  Crown Heights  40.67560  -73.92510
# 33740      Momo               Bronx       Allerton  40.86659  -73.86600
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 19877     Private room     85               3                 48  2019-06-24
# 28876     Private room     60               2                  1  2018-01-03
# 20171  Entire home/apt    210               2                  4  2018-06-03
# 43801     Private room    100               3                  2  2019-06-19
# 33740     Private room     34               2                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 19877               1.51                               3                44
# 28876               0.05                               1                 0
# 20171               0.13                               2                 0
# 43801               1.33                               1               163
# 33740                NaN                               1                 0

# %%
df2.price.describe()
# Out:
# count    48183.000000
# mean       148.772036
# std        153.594795
# min         31.000000
# 25%         70.000000
# 50%        110.000000
# 75%        179.000000
# max       2999.000000
# Name: price, dtype: float64

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64
